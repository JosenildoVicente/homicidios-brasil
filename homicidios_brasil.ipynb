# %% [markdown]
# # Carregamento dos conjuntos de dados

# %%
import pandas as pd
import numpy as np

# %%
homicidios = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios.csv", encoding="ISO-8859-1",sep=";")
homicidios_negros = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-negros.csv", encoding="ISO-8859-1",sep=";")
homicidios_nao_negros = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-nao-negros.csv", encoding="ISO-8859-1",sep=";")
homicidios_armas_fogo = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-por-armas-de-fogo.csv", encoding="ISO-8859-1",sep=";")
homicidios_homens = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-homens.csv", encoding="ISO-8859-1",sep=";")
homicidios_homens_negros = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-homens-negros.csv", encoding="ISO-8859-1",sep=";")
homicidios_homens_nao_negros = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-homens-nao-negros.csv", encoding="ISO-8859-1",sep=";")
homicidios_homens_armas_fogo = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-de-homens-por-armas-de-fogo.csv", encoding="ISO-8859-1",sep=";")
homicidios_mulheres = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-mulheres.csv", encoding="ISO-8859-1",sep=";")
homicidios_mulheres_negras = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-mulheres-negras.csv", encoding="ISO-8859-1",sep=";")
homicidios_mulheres_nao_negras = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-mulheres-nao-negras.csv", encoding="ISO-8859-1",sep=";")
homicidios_mulheres_armas_fogo = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/homicidios-de-mulheres-por-armas-de-fogo.csv", encoding="ISO-8859-1",sep=";")

taxa_homicidios = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-homicidios.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_negros = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-de-homicidios-negros.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_nao_negros = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-de-homicidios-nao-negros.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_armas_fogo = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-de-homicidios-por-armas-de-fogo.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_homens = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-de-homicidios-homens.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_homens_negros = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-de-homicidios-homens-negros.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_homens_nao_negros = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-de-homicidios-homens-nao-negros.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_homens_armas_fogo = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-de-homicidios-de-homens-por-armas-de-fogo.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_mulheres = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-de-homicidios-mulheres.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_mulheres_negras = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-de-homicidios-mulheres-negras.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_mulheres_nao_negras = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxa-de-homicidios-mulheres-nao-negras.csv", encoding="ISO-8859-1",sep=";")
taxa_homicidios_mulheres_armas_fogo = pd.read_csv( "https://raw.githubusercontent.com/JosenildoVicente/homicidios-brasil/main/datasets/taxade-homicidio-de-mulheres-por-armas-de-fogo.csv", encoding="ISO-8859-1",sep=";")

# %%
homicidios = homicidios.rename(columns ={'perÃ­odo':'ano','valor':'homicidios'})
homicidios_negros = homicidios_negros.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_negros'})
homicidios_nao_negros = homicidios_nao_negros.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_nao_negros'})
homicidios_armas_fogo = homicidios_armas_fogo.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_armas_fogo'})
homicidios_homens = homicidios_homens.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_homens'})
homicidios_homens_negros = homicidios_homens_negros.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_homens_negros'})
homicidios_homens_nao_negros = homicidios_homens_nao_negros.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_homens_nao_negros'})
homicidios_homens_armas_fogo = homicidios_homens_armas_fogo.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_homens_armas_fogo'})
homicidios_mulheres = homicidios_mulheres.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_mulheres'})
homicidios_mulheres_negras = homicidios_mulheres_negras.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_mulheres_negras'})
homicidios_mulheres_nao_negras = homicidios_mulheres_nao_negras.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_mulheres_nao_negras'})
homicidios_mulheres_armas_fogo = homicidios_mulheres_armas_fogo.rename(columns ={'perÃ­odo':'ano','valor':'homicidios_mulheres_armas_fogo'})

taxa_homicidios = taxa_homicidios.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios'})
taxa_homicidios_negros = taxa_homicidios_negros.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_negros'})
taxa_homicidios_nao_negros = taxa_homicidios_nao_negros.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_nao_negros'})
taxa_homicidios_armas_fogo = taxa_homicidios_armas_fogo.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_armas_fogo'})
taxa_homicidios_homens = taxa_homicidios_homens.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_homens'})
taxa_homicidios_homens_negros = taxa_homicidios_homens_negros.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_homens_negros'})
taxa_homicidios_homens_nao_negros = taxa_homicidios_homens_nao_negros.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_homens_nao_negros'})
taxa_homicidios_homens_armas_fogo = taxa_homicidios_homens_armas_fogo.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_homens_armas_fogo'})
taxa_homicidios_mulheres = taxa_homicidios_mulheres.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_mulheres'})
taxa_homicidios_mulheres_negras = taxa_homicidios_mulheres_negras.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_mulheres_negras'})
taxa_homicidios_mulheres_nao_negras = taxa_homicidios_mulheres_nao_negras.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_mulheres_nao_negras'})
taxa_homicidios_mulheres_armas_fogo = taxa_homicidios_mulheres_armas_fogo.rename(columns ={'perÃ­odo':'ano','valor':'taxa_homicidios_mulheres_armas_fogo'})

# %%
teste = [homicidios_negros, homicidios_nao_negros, homicidios_armas_fogo, homicidios_homens, homicidios_homens_negros, homicidios_homens_nao_negros, homicidios_homens_armas_fogo, homicidios_mulheres, homicidios_mulheres_negras, homicidios_mulheres_nao_negras, homicidios_mulheres_armas_fogo, taxa_homicidios, taxa_homicidios_negros, taxa_homicidios_nao_negros, taxa_homicidios_armas_fogo, taxa_homicidios_homens, taxa_homicidios_homens_negros, taxa_homicidios_homens_nao_negros, taxa_homicidios_homens_armas_fogo, taxa_homicidios_mulheres, taxa_homicidios_mulheres_negras, taxa_homicidios_mulheres_nao_negras, taxa_homicidios_mulheres_armas_fogo]
for i in teste:
  homicidios = pd.merge(homicidios, i, how='left',on=['cod','nome','ano'])

# %%
homicidios.columns
# Out:
# Index(['cod', 'nome', 'ano', 'homicidios', 'homicidios_negros',
#        'homicidios_nao_negros', 'homicidios_armas_fogo', 'homicidios_homens',
#        'homicidios_homens_negros', 'homicidios_homens_nao_negros',
#        'homicidios_homens_armas_fogo', 'homicidios_mulheres',
#        'homicidios_mulheres_negras', 'homicidios_mulheres_nao_negras',
#        'homicidios_mulheres_armas_fogo', 'taxa_homicidios',
#        'taxa_homicidios_negros', 'taxa_homicidios_nao_negros',
#        'taxa_homicidios_armas_fogo', 'taxa_homicidios_homens',
#        'taxa_homicidios_homens_negros', 'taxa_homicidios_homens_nao_negros',
#        'taxa_homicidios_homens_armas_fogo', 'taxa_homicidios_mulheres',
#        'taxa_homicidios_mulheres_negras',
#        'taxa_homicidios_mulheres_nao_negras',
#        'taxa_homicidios_mulheres_armas_fogo'],
#       dtype='object')

# %%
homicidios.head(27)
# Out:
#     cod nome   ano  homicidios  homicidios_negros  homicidios_nao_negros  \
# 0    41   PR  1989        1112                NaN                    NaN
# 1    53   DF  1989         331                NaN                    NaN
# 2    52   GO  1989         810                NaN                    NaN
# 3    51   MT  1989         471                NaN                    NaN
# 4    50   MS  1989         371                NaN                    NaN
# 5    43   RS  1989        1561                NaN                    NaN
# 6    42   SC  1989         354                NaN                    NaN
# 7    11   RO  1989         490                NaN                    NaN
# 8    12   AC  1989          95                NaN                    NaN
# 9    13   AM  1989         321                NaN                    NaN
# 10   14   RR  1989         113                NaN                    NaN
# 11   15   PA  1989         666                NaN                    NaN
# ...
